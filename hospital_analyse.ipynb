# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
hospitals = pd.read_csv('data/Hospital_Rank.csv')
print hospitals.loc[:,['Country','Hospital']].groupby("Country").count().describe()
hospitals.loc[:,['Country','Hospital']].groupby("Country").count()
# Out:
#           Hospital
# count   134.000000
# mean     91.738806
# std     340.255298
# min       1.000000
# 25%       2.000000
# 50%      10.000000
# 75%      58.000000
# max    3619.000000
#                                  Hospital
# Country
# Argentina                              71
# Armenia                                 4
# Aruba                                   1
# Australia                             116
# Austria                                72
# Bahrain                                 5
# Bangladesh                             17
# Barbados                                2
# Belarus                                10
# Belgium                               133
# Belize                                  1
# Bermuda                                 2
# Bhutan                                  1
# Bosnia and Herzegovina                  6
# Brazil                                214
# Brunei Darussalam                       2
# Bulgaria                               35
# ...
